# %%
a=12345
a
# Out:
# 12345

# %%
3+5
# Out:
# 8

# %%
print(a)
# Out:
# 12345

# %%
plint("hello World")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a358cc092e4d> in <cell line: 1>()
# ----> 1 plint("hello World")
#
# NameError: name 'plint' is not defined

# %%
print("Helo World")
# Out:
# Helo World

# %% [markdown]
# # 第１章

# %% [markdown]
# # 新しいセクション

# %%
from PIL import Image, ImageDraw

# %%
from PIL import Image, ImageDraw

img = Image.new("L", (256, 256), 255)
draw = ImageDraw.Draw(img)
cx = 128
cy = 128
r = 96
draw.ellipse((cx-r,cy-r,cx+r,cy+r))
